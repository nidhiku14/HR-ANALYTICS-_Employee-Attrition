# %% [markdown]
# ***HR ANALYTICS***

# %% [markdown]
# In this project we will implement Random forest classifiers and understand reason behind  employee attrition . This analysis will help the HR to know the reasons behind employees leaving the firm.

# %% [markdown]
# ![hr.png](data:image/png;base64,...)

# %% [markdown]
# **Importing libraries for our project**

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import io
import matplotlib.pyplot as plt
from google.colab import files
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %% [markdown]
# **Loading and Reading datasets**

# %%
uploaded = files.upload()
 
df = pd.read_csv(io.BytesIO(uploaded['WA_Fn-UseC_-HR-Employee-Attrition.csv']))
# Out:
#      <input type="file" id="files-95454b3c-d460-427a-9a76-37a4c59c7ba3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95454b3c-d460-427a-9a76-37a4c59c7ba3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WA_Fn-UseC_-HR-Employee-Attrition.csv to WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
df.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
#descibing statstical things
df.describe()
# Out:
#        BusinessTravel    DailyRate  ...  YearsWithCurrManager          Yes
# count     1470.000000  1470.000000  ...           1470.000000  1470.000000
# mean         1.607483   443.074830  ...              4.123129     0.161224
# std          0.665455   253.513199  ...              3.568136     0.367863
# min          0.000000     0.000000  ...              0.000000     0.000000
# 25%          1.000000   225.000000  ...              2.000000     0.000000
# 50%          2.000000   447.000000  ...              3.000000     0.000000
# 75%          2.000000   660.000000  ...              7.000000     0.000000
# max          2.000000   885.000000  ...             17.000000     1.000000
#
# [8 rows x 33 columns]

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# No null values so we can proceed further

# %% [markdown]
# **Data Visualization**

# %%
attrition_count = pd.DataFrame(df['Attrition'].value_counts())
attrition_count
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc7f1472e10>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899548, 'Yes')])

# %%
df.drop(['EmployeeCount' , 'EmployeeNumber'] , axis = 1)
# Out:
#       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 33 columns]

# %%
attrition_dummies = pd.get_dummies(df['Attrition'])
attrition_dummies.head(10)
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   0    1
# 3   1    0
# 4   1    0
# 5   1    0
# 6   1    0
# 7   1    0
# 8   1    0
# 9   1    0

# %%
df = pd.concat([df, attrition_dummies] , axis = 1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  ...  YearsWithCurrManager No  Yes
# 0   41       Yes      Travel_Rarely  ...                     5  0    1
# 1   49        No  Travel_Frequently  ...                     7  1    0
# 2   37       Yes      Travel_Rarely  ...                     0  0    1
# 3   33        No  Travel_Frequently  ...                     0  1    0
# 4   27        No      Travel_Rarely  ...                     2  1    0
#
# [5 rows x 37 columns]

# %%
df = df.drop(['Attrition' , 'No'] , axis = 1)
df.head()
# Out:
#    Age     BusinessTravel  ...  YearsWithCurrManager Yes
# 0   41      Travel_Rarely  ...                     5   1
# 1   49  Travel_Frequently  ...                     7   0
# 2   37      Travel_Rarely  ...                     0   1
# 3   33  Travel_Frequently  ...                     0   0
# 4   27      Travel_Rarely  ...                     2   0
#
# [5 rows x 35 columns]

# %%
sns.barplot(x = 'Gender' , y = 'Yes', data = df)

# %%
sns.barplot(x = 'Department', y = 'Yes', data = df)

# %%
sns.barplot(x = 'BusinessTravel', y = 'Yes', data = df)

# %%
#corelation map
plt.figure(figsize = (10,6))
sns.heatmap(df.corr())

# %%
df = df.drop(['Age' , 'JobLevel'], axis = 1)
#age and job level is not required for further analysis ,so we dropped it

# %% [markdown]
# **Data Preprocessing**

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **Model Building**

# %%
#checking the feature importance in the model to highlight which features may be most relevant to the target
plt.figure(figsize=(9,7))
n_features = x_train.shape[1]
plt.barh(range(n_features), rf.feature_importances_, align='center')
plt.yticks(np.arange(n_features), x_train.columns)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.show()

# %%
#We are going to use random forest classifer 
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

# %%
x  = df.drop(['Yes'], axis = 1)
y = df['Yes']

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
x_train.head()
# Out:
#      BusinessTravel  DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 338               2        295  ...                        1                     2
# 363               2        159  ...                        0                     0
# 759               2        437  ...                        0                     4
# 793               2        502  ...                        2                     2
# 581               2        516  ...                        0                     2
#
# [5 rows x 32 columns]

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
rf.score(x_train, y_train)
# Out:
# 0.9815354713313897

# %% [markdown]
# **Predicting for x_test**

# %%
pred = rf.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.8526077097505669

# %% [markdown]
# **Our Accuracy for Tested Data = 85.26 %**
